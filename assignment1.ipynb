# %% [markdown]
# <a href="https://colab.research.google.com/github/wolffromothersideoftheplanet/assignment/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as nm
import pandas as pd

# %%
df=pd.read_csv('/content/House Price India.csv')
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df['id'].unique()
# Out:
# array([6762810145, 6762810635, 6762810998, ..., 6762830618, 6762830709,
#        6762831463])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['id']= le.fit_transform(df['id'])

# %%
df['id'].unique()
# Out:
# array([   84,   398,   647, ..., 13943, 14015, 14519])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
x = df.drop('Built Year',axis=1)
x
# Out:
#           id   Date  number of bedrooms  number of bathrooms  living area  \
# 0         84  42491                   5                 2.50         3650
# 1        398  42491                   4                 2.50         2920
# 2        647  42491                   5                 2.75         2910
# 3       1735  42491                   4                 2.50         3310
# 4       1951  42491                   3                 2.00         2710
# ...      ...    ...                 ...                  ...          ...
# 14615  13691  42734                   2                 1.50         1556
# 14616  13748  42734                   3                 2.00         1680
# 14617  13943  42734                   2                 1.00         1070
# 14618  14015  42734                   4                 1.00         1030
# 14619  14519  42734                   3                 1.00          900
#
#        lot area  number of floors  waterfront present  number of views  \
# ...

# %%
y=df['Built Year']
y
# Out:
# 0        1921
# 1        1909
# 2        1939
# 3        2001
# 4        1929
#          ...
# 14615    1957
# 14616    1968
# 14617    1962
# 14618    1955
# 14619    1969
# Name: Built Year, Length: 14620, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=12)

# %%
xtrain
# Out:
#           id   Date  number of bedrooms  number of bathrooms  living area  \
# 12389   8341  42686                   2                 1.50         1210
# 5425    7248  42572                   5                 3.00         2260
# 1287   12881  42511                   4                 2.75         2570
# 13440   5598  42707                   3                 2.25         1240
# 6988    1345  42595                   4                 2.50         3680
# ...      ...    ...                 ...                  ...          ...
# 7409   12201  42601                   5                 1.75         2170
# 3325   10196  42543                   3                 1.00         1270
# 9606   10762  42637                   4                 1.00         1360
# 5787    6053  42576                   3                 1.00         1020
# 14155   1831  42721                   5                 3.00         4080
#
#        lot area  number of floors  waterfront present  number of views  \
# ...

# %%
xtest
# Out:
#           id   Date  number of bedrooms  number of bathrooms  living area  \
# 12149   3719  42683                   3                 1.00         1210
# 13581   3603  42711                   3                 1.00         1430
# 11595  10869  42671                   3                 1.00         1490
# 2769    9458  42536                   3                 1.00         1770
# 7393    9915  42601                   4                 2.50         2390
# ...      ...    ...                 ...                  ...          ...
# 7362    6269  42601                   4                 2.25         2250
# 11132   8714  42664                   3                 1.75         1470
# 142     9609  42494                   3                 3.00         1571
# 1405   12231  42515                   3                 1.00         1140
# 6184    4798  42582                   4                 1.75         2400
#
#        lot area  number of floors  waterfront present  number of views  \
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
reg = Sequential()
reg.add(Dense(4,activation='relu'))
reg.add(Dense(12,activation='relu'))
reg.add(Dense(32,activation='relu'))
reg.add(Dense(1,activation='linear'))

# %%
reg.compile(optimizer='adam',loss='mse',metrics=['mse'])

# %%
reg.fit(xtrain,ytrain,batch_size=10,epochs=20,validation_data=(xtest,ytest))
# Out:
# Epoch 1/20
# 1170/1170 [==============================] - 4s 2ms/step - loss: 3885995.0000 - mse: 3885995.0000 - val_loss: 3883134.0000 - val_mse: 3883134.0000
# Epoch 2/20
# 1170/1170 [==============================] - 3s 2ms/step - loss: 3885996.0000 - mse: 3885996.0000 - val_loss: 3883134.0000 - val_mse: 3883134.0000
# Epoch 3/20
# 1170/1170 [==============================] - 3s 3ms/step - loss: 3885993.7500 - mse: 3885993.7500 - val_loss: 3883134.0000 - val_mse: 3883134.0000
# Epoch 4/20
# 1170/1170 [==============================] - 3s 2ms/step - loss: 3885989.7500 - mse: 3885989.7500 - val_loss: 3883134.0000 - val_mse: 3883134.0000
# Epoch 5/20
# 1170/1170 [==============================] - 2s 2ms/step - loss: 3885992.5000 - mse: 3885992.5000 - val_loss: 3883134.0000 - val_mse: 3883134.0000
# Epoch 6/20
# 1170/1170 [==============================] - 3s 2ms/step - loss: 3885988.5000 - mse: 3885988.5000 - val_loss: 3883134.0000 - val_mse: 3883134.0000
# Epoch 7/20
# ...
